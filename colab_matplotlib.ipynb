# %% [markdown]
# <a href="https://colab.research.google.com/github/seongjinNa1/mataplotlib/blob/main/colab_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# t 값을 0부터 2pi까지 생성
t = np.linspace(0, 2 * np.pi, 1000)

# 하트 모양을 그리는 x, y 식
x = 16 * np.sin(t)**3
y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

plt.figure(figsize=(6,6))
plt.plot(x, y, color='red', linewidth=3)
plt.fill_between(x, y, color='red', alpha=0.6)  # 하트 내부 채우기
plt.title('Heart Shape with Matplotlib')
plt.axis('equal')
plt.axis('off')  # 축 감추기
plt.show()
